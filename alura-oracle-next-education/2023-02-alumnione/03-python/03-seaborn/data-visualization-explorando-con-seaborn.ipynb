# %% [markdown]
# # **1. Importando y traduciendo variables**

# %% [markdown]
# ## Importando base de datos

# %%
import pandas as pd

# %%
pd.read_csv('./data/credit_card.csv')
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# 3      14522.9563    602.2000        0
# 4     124060.1253  16560.5000        0
# ...           ...         ...      ...
# 1495     295.0780      0.0000        1
# 1496   23637.8555   1144.1800        0
# 1497     962.9178    962.9178        0
# 1498     864.7592    864.7592        0
# 1499   97022.8508  97022.8508        0
#
# [1500 rows x 8 columns]

# %%
datos = pd.read_csv('./data/credit_card.csv')

# %%
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %% [markdown]
# ## Traduciendo variables

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
dic_columnas = {
    'LIMIT_BAL' : 'limite',
    'CHECKING_ACCOUNT' : 'cuenta_corriente',
    'EDUCATION' : 'escolaridad',
    'MARRIAGE' : 'estado_civil',
    'AGE' : 'edad',
    'BILL_AMT' : 'valor_factura',
    'PAY_AMT' : 'valor_pago',
    'DEFAULT' : 'moroso'
}

# %%
tarjetas = datos.rename(columns = dic_columnas)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dic_cuenta = {
    'Yes' : 'Si',
    'No' : 'No'
}

# %%
tarjetas.cuenta_corriente.map(dic_cuenta)
# Out:
# 0       Si
# 1       Si
# 2       Si
# 3       Si
# 4       No
#         ..
# 1495    Si
# 1496    No
# 1497    No
# 1498    No
# 1499    No
# Name: cuenta_corriente, Length: 1500, dtype: object

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente = tarjetas.cuenta_corriente.map(dic_cuenta)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022               Si       2.University      Married    24
# 1   36132               Si       2.University       Single    26
# 2   27099               Si       2.University       Single    34
# 3   15055               Si       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.escolaridad.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dic_escolaridad = {
    '2.University' : '2.Universidad',
    '3.Graduate School' : '3.Pos-graduación',
    '1.High School' : '1.Colegio'
}

# %%
tarjetas.escolaridad = tarjetas.escolaridad.map(dic_escolaridad)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad      Married    24
# 1   36132               Si     2.Universidad       Single    26
# 2   27099               Si     2.Universidad       Single    34
# 3   15055               Si     2.Universidad      Married    37
# 4  150550               No  3.Pos-graduación       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.estado_civil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dic_estado_civil = {
    'Married' : 'Casadx',
    'Single' : 'Solterx'
}

# %%
tarjetas.estado_civil = tarjetas.estado_civil.map(dic_estado_civil)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casadx    24
# 1   36132               Si     2.Universidad      Solterx    26
# 2   27099               Si     2.Universidad      Solterx    34
# 3   15055               Si     2.Universidad       Casadx    37
# 4  150550               No  3.Pos-graduación      Solterx    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# # **2. Análisis exploratorio de variables**

# %% [markdown]
# ## Importando Seaborn y análisis de distribución

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: C:\Users\Julio\miniconda3\Lib\site-packages
# Requires: matplotlib, numpy, pandas
# Required-by:

# %%
tarjetas.shape
# Out:
# (1500, 8)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casadx    24
# 1   36132               Si     2.Universidad      Solterx    26
# 2   27099               Si     2.Universidad      Solterx    34
# 3   15055               Si     2.Universidad       Casadx    37
# 4  150550               No  3.Pos-graduación      Solterx    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
sns.distplot(tarjetas['limite'])
# Out:
# C:\Users\Julio\AppData\Local\Temp\ipykernel_2700\2159032894.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tarjetas['limite'])
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='limite', ylabel='Density'>

# %%
sns.displot(data = tarjetas, x = 'limite', hue = 'escolaridad');
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Creando variable numérica

# %%
tarjetas['iu'] = tarjetas['valor_factura'] / tarjetas['limite']
tarjetas.head().round(4)
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casadx    24
# 1   36132               Si     2.Universidad      Solterx    26
# 2   27099               Si     2.Universidad      Solterx    34
# 3   15055               Si     2.Universidad       Casadx    37
# 4  150550               No  3.Pos-graduación      Solterx    29
#
#    valor_factura  valor_pago  moroso      iu
# 0       934.0122      0.0000       1  0.1551
# 1       519.3975      0.0000       1  0.0144
# 2      4223.5297    457.0698       0  0.1559
# 3     14522.9563    602.2000       0  0.9647
# 4    124060.1253  16560.5000       0  0.8240

# %%
sns.displot(data = tarjetas, x = 'iu');
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# > Podemos apreciar en la gráfica que existe una cantidad signficativa de usuarios que sólo usa un poco del límite que tienen disponible

# %% [markdown]
# ## Parámetros de gráficos

# %%
sns.set_style('darkgrid')
sns.displot(data = tarjetas, x = 'limite', hue = 'escolaridad', palette = 'inferno_r');
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # **3. Comparando y analizando variables categóricas**

# %% [markdown]
# ## Countplot, catplot y swarmplot

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casadx    24
# 1   36132               Si     2.Universidad      Solterx    26
# 2   27099               Si     2.Universidad      Solterx    34
# 3   15055               Si     2.Universidad       Casadx    37
# 4  150550               No  3.Pos-graduación      Solterx    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
tarjetas['moroso'] = tarjetas['moroso'].astype(str)
sns.countplot(x = 'cuenta_corriente', data = tarjetas, hue = 'moroso', palette = 'coolwarm');

# %%
sns.catplot(x = 'estado_civil', y = 'limite', data = tarjetas, hue = 'moroso', dodge = True);
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.swarmplot(data = tarjetas, x = 'escolaridad', y = 'iu');
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 27.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Boxplot y Violinplot

# %%
sns.boxplot(data = tarjetas, x = 'escolaridad', y = 'iu', hue = 'moroso', palette = 'bone');

# %%
sns.violinplot(data = tarjetas, x = 'escolaridad', y = 'iu', hue = 'moroso', palette = 'bone');

# %% [markdown]
# ## Creando y analizando variable categórica

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casadx    24
# 1   36132               Si     2.Universidad      Solterx    26
# 2   27099               Si     2.Universidad      Solterx    34
# 3   15055               Si     2.Universidad       Casadx    37
# 4  150550               No  3.Pos-graduación      Solterx    29
#
#    valor_factura  valor_pago moroso        iu
# 0       934.0122      0.0000      1  0.155100
# 1       519.3975      0.0000      1  0.014375
# 2      4223.5297    457.0698      0  0.155856
# 3     14522.9563    602.2000      0  0.964660
# 4    124060.1253  16560.5000      0  0.824046

# %%
tarjetas.edad.unique()
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72],
#       dtype=int64)

# %%
bins = [20, 30, 40, 50, 100]
nombres = ['20-30', '30-40', '40-50', '50+']

tarjetas['rango_edad'] = pd.cut(tarjetas['edad'], bins, labels = nombres)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casadx    24
# 1   36132               Si     2.Universidad      Solterx    26
# 2   27099               Si     2.Universidad      Solterx    34
# 3   15055               Si     2.Universidad       Casadx    37
# 4  150550               No  3.Pos-graduación      Solterx    29
#
#    valor_factura  valor_pago moroso        iu rango_edad
# 0       934.0122      0.0000      1  0.155100      20-30
# 1       519.3975      0.0000      1  0.014375      20-30
# 2      4223.5297    457.0698      0  0.155856      30-40
# 3     14522.9563    602.2000      0  0.964660      30-40
# 4    124060.1253  16560.5000      0  0.824046      20-30

# %%
sns.boxplot(data = tarjetas, x = 'rango_edad', y = 'limite');
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # **4. Análisis de variables numéricas y regresión**

# %% [markdown]
# ## Displot

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casadx    24
# 1   36132               Si     2.Universidad      Solterx    26
# 2   27099               Si     2.Universidad      Solterx    34
# 3   15055               Si     2.Universidad       Casadx    37
# 4  150550               No  3.Pos-graduación      Solterx    29
#
#    valor_factura  valor_pago moroso        iu rango_edad
# 0       934.0122      0.0000      1  0.155100      20-30
# 1       519.3975      0.0000      1  0.014375      20-30
# 2      4223.5297    457.0698      0  0.155856      30-40
# 3     14522.9563    602.2000      0  0.964660      30-40
# 4    124060.1253  16560.5000      0  0.824046      20-30

# %%
sns.displot(data = tarjetas, x = 'limite', col = 'escolaridad', kind='kde', hue = 'rango_edad');
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(

# %% [markdown]
# ## Scatterplot y Lmplot

# %%
sns.scatterplot(data = tarjetas, x = 'iu', y = 'valor_factura', hue = 'cuenta_corriente');

# %%
sns.lmplot(data = tarjetas, x = 'iu', y = 'valor_factura');

# %% [markdown]
# ## Test de hipótesis

# %%
sns.lmplot(data = tarjetas, x = 'iu', y = 'valor_factura', col = 'moroso');

# %%
from scipy.stats import ranksums

# %% [markdown]
# H<sup>null<sup>
#
# La distribución de los grupos moroso y no moroso es la misma

# %% [markdown]
# **H<sup>alt<sup>**
#
# **La distribución de los grupos moroso y no moroso no es la misma**

# %%
moroso = tarjetas.query("moroso == 1").valor_factura
moroso
# Out:
# Series([], Name: valor_factura, dtype: float64)

# %%
no_moroso = tarjetas.query("moroso == 0").valor_factura
no_moroso
# Out:
# Series([], Name: valor_factura, dtype: float64)

# %%
resultado = ranksums(moroso, no_moroso)
print("El p_value de nuestro test es {}".format(resultado.pvalue))
# Out:
# El p_value de nuestro test es nan
# C:\Users\Julio\miniconda3\Lib\site-packages\scipy\stats\_stats_py.py:9205: RuntimeWarning: invalid value encountered in scalar divide
#   z = (s - expected) / np.sqrt(n1*n2*(n1+n2+1)/12.0)

# %% [markdown]
# # **5. Análisis conjunto de variables**

# %% [markdown]
# ## Joinplot

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casadx    24
# 1   36132               Si     2.Universidad      Solterx    26
# 2   27099               Si     2.Universidad      Solterx    34
# 3   15055               Si     2.Universidad       Casadx    37
# 4  150550               No  3.Pos-graduación      Solterx    29
#
#    valor_factura  valor_pago moroso        iu rango_edad
# 0       934.0122      0.0000      1  0.155100      20-30
# 1       519.3975      0.0000      1  0.014375      20-30
# 2      4223.5297    457.0698      0  0.155856      30-40
# 3     14522.9563    602.2000      0  0.964660      30-40
# 4    124060.1253  16560.5000      0  0.824046      20-30

# %%
sns.jointplot(data = tarjetas, x = 'edad', y = 'limite', kind = 'hex');
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(data = tarjetas, x = 'edad', y = 'limite', kind = 'kde', hue = 'moroso');
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Pairplot

# %%
tarjetas.describe()
# Out:
#               limite         edad  valor_factura    valor_pago           iu
# count    1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean    51221.943333    35.212667   15459.869900   1984.869266     0.388237
# std     39424.407462     9.274955   20722.582831   5296.771686     0.341923
# min      3011.000000    21.000000      27.701200      0.000000     0.000188
# 25%     18066.000000    28.000000    2035.586550    407.011925     0.049209
# 50%     42154.000000    33.500000    7701.385250    759.374200     0.308976
# 75%     72264.000000    41.000000   20671.568850   1705.279850     0.704090
# max    210770.000000    75.000000  141792.506500  97022.850800     0.998010

# %%
sns.pairplot(data = tarjetas, hue = 'escolaridad', palette = 'cividis');
# Out:
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Julio\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
